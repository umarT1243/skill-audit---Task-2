# %% [markdown]
# pip install matplotlib

# %% [markdown]
# $\huge i.$ Plot the following function with appropriate labels and titles.
#
#
# 𝑦 = e^
# (−x)
# sin (2𝑥 +
# 𝜋/
# 3
# ) , − 2𝜋 ≤ 𝑥 ≤ 2𝜋

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the range of  x values from, -2𝜋 to 2𝜋
x= np.arange(-2*np.pi, 2*np.pi, 0.01)

# Calculate the y values using the given function
y = np.exp(-x) * np.sin(2*x + np.pi/3)


# Add labels and title
plt.xlabel("x-values")
plt.ylabel("y-values")
plt.title("y = e^(-x)sin(2x + pi/3)")


# Plot the function
plt.plot(x, y)

# Show the plot
plt.show()

# %% [markdown]
# $\huge ii.$ Generate the term 𝑛 of a recursive relationship given by
#
#
# 𝑎𝑛 = 5𝑎𝑛−1 + 2 , 𝑎0 = 2

# %%
def recursive(n, a0=2):
    if n == 0:
        return a0
    else:
        return 5 * recursive(n-1) + 2

n = int(input("Enter the value of n: "))
print("The nth term of the recursive relationship is:", recursive(n))
# Out:
# The nth term of the recursive relationship is: 610351562

# %% [markdown]
# $\huge iii. $ Develop a python script to generate a 3-digit random pin number (all integers)

# %%
import random

pin = random.randint(100, 999)
print("Pin Number = ",pin)
# Out:
# Pin Number =  185

# %% [markdown]
# $\huge iv. $ Develop a python script to find the 3-digit pin number in the previous task. Assume that
# we do not know the pin number (or forgot the pin) and the script should find be able to
# restore the pin.

# %%
restore = pin

for i in range(100, 1000):
    if i == pin:
        print("Your Pin Has Been Restored:", i)
# Out:
# Your Pin Has Been Restored: 185

# %% [markdown]
# $\huge v. $ Reflect on sub-tasks (iii) and (iv), can you give examples of applications of the script in
# real-world applications?

# %% [markdown]
# 1) The first example of sub-task (iii) being used in the real world , would be in a place of banking. the script would generate a random 3 digit pin for the customer and give them this pin via email or post.
# Sub-task (iv) could be used if the customer forgets the pin in question, and would be able to get it sent to them again via email or post.
#
# 2) The second example of sub-task (iii) being used in the real world , would be creating a PIN for a mobile phone so that the owner may input it to unlock it.
# Sub-task (iv) could be used if the user forgets the pin to the device they can restore it by completing a set of security messures.
#
# 3) The third example of sub-task (iii) being used in the real world , would be in a scenario where a worker would use a 3 digit pin to gain access to the building where they work.
# Sub-task (iv) could be used if the worker forgets their pin and will be able to restore this pin from the system.
